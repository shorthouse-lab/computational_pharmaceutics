# %% [markdown]
# # PHAY0076: Computational Pharmaceutics — Coursework 2 (2026)
#
# ## From molecule to formulation: predicting formulation strategy from molecular structure

# %% [markdown]
# **IMPORTANT**
# - Work individually.
# - Save your notebook with your **examination number** appended to the filename (e.g., `Coursework2_12345678.ipynb`).
# - Export an **HTML** version: `File → Save and Export Notebook As… → HTML`.
# - Upload the `.html` file.
#
# ## Context
#
# A pharmaceutical company has compiled a historical dataset of small-molecule drug candidates and the **formulation strategy** that was judged most suitable for each compound after early development screening.
#
# Your job is to investigate whether **molecular structure** can help predict the most suitable formulation strategy for a new molecule.
#
# You will:
# 1. Load and clean a molecular dataset containing **SMILES strings**
# 2. Convert SMILES into molecular representations
# 3. Calculate chemically meaningful descriptors
# 4. Explore relationships between molecular properties and formulation strategy
# 5. Use unsupervised learning to visualise chemical space
# 6. Build a simple classification model to predict formulation strategy
# 7. Summarise what kinds of molecules tend to require different formulation approaches
#
# ## Dataset
#
# The data are provided as a CSV file:
#
# `molecule_formulation_dataset_2026.csv`
#
# Place the file in the **same folder** as this notebook before running.
#
# ### Expected columns
# - `Molecule_ID`
# - `SMILES`
# - `Best_Formulation`
#
# ### Formulation classes
# - `IR_tablet`
# - `ASD`
# - `Lipid_system`
#
# ## Marking (100%)
# - Section 1: Data loading and molecular cleaning — **10%**
# - Section 2: Descriptor calculation and summary statistics — **15%**
# - Section 3: Visualisation and exploratory analysis — **20%**
# - Section 4: Unsupervised learning — **15%**
# - Section 5: Supervised learning — **20%**
# - Section 6: Prediction of a new molecule - **10%**
# - Section 7: Summary and formulation interpretation — **10%**
#
# ## Notes
# - Can can double click on any cell to edit it - including the markdown cells.
# - You are **not** expected to tune models extensively. You will not be scored on the accuracy of your models, just on implementation and interpretation
# - You are **not** expected to use deep learning or graph neural networks.
# - Any reasonable implementation is acceptable, but use of `pandas`, `rdkit`, `seaborn`, and `scikit-learn` is recommended.
# - If some SMILES strings cannot be parsed, this is part of the data cleaning task.

# %% [markdown]
# ## Insert your examination number here:
# **Exam number:** `__________`

# %%
# =========================
# Setup (some initial libraries - you will need to load more for downstream tasks but this can get you started)
# =========================

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

## Code for loading the data into google colab

# %% [markdown]
# # Section 1 — Data loading and molecular cleaning (10%)
#
# ## Tasks
# 1. Load the dataset from `molecule_formulation_dataset_2026.csv` into a dataframe `df`.
# 2. Inspect the dataframe structure and contents:
#    - `head()`, `shape`, `info()`, `describe()`
# 3. Check for:
#    - missing values
#    - duplicate rows
#    - invalid or unparsable SMILES strings
# 4. Convert the `SMILES` column into RDKit molecule objects and store them in a new column.
# 5. Create a cleaned dataframe `df_clean` for downstream analysis.
#
# ## Questions
# **Q1 (5%)** Were there any missing values, duplicate rows, or invalid SMILES? How did you handle them?
#
# **Q2 (5%)** Why is checking whether SMILES can be parsed an important part of molecular data cleaning?

# %%
# Your code for Section 1 goes here

# %% [markdown]
# # Section 2 — Descriptor calculation and summary statistics (15%)
#
# A molecule’s behaviour is influenced by its physicochemical properties. In this section, you will calculate a small set of common descriptors that are relevant to formulation.
#
# ## Tasks
#
# Using your cleaned dataframe, calculate the following descriptors for each molecule:
#
# - Molecular weight (`MolWt`)
# - LogP (`MolLogP`)
# - Topological polar surface area (`TPSA`)
# - Hydrogen bond donors (`HBD`)
# - Hydrogen bond acceptors (`HBA`)
# - Number of rotatable bonds (`RotBonds`)
# - Number of aromatic rings (`AromaticRings`)
#
# Store these in new dataframe columns.
#
# Then:
# 1. Inspect the descriptor table
# 2. Produce summary statistics for the descriptors
#
# ## Questions
# **Q3 (10%)** Which descriptors show the greatest variation across the dataset? Comment on at least **two** features of the descriptor distributions using summary statistics.
#
# **Q4 (5%)** Why might descriptors such as LogP, TPSA, and molecular weight be relevant when deciding on a formulation strategy?

# %%
# Your code for Section 2 goes here

# %% [markdown]
# # Section 3 — Visualisation and exploratory analysis (20%)
#
# ## Tasks
# Using your cleaned dataframe and your descriptor columns:
#
# 1. Plot distributions (histogram or KDE) for:
#    - `MolWt`
#    - `MolLogP`
#    - `TPSA`
#
# 2. Create scatter plots:
#    - `MolWt` vs `MolLogP` coloured by `Best_Formulation`
#    - `MolLogP` vs `TPSA` coloured by `Best_Formulation`
#
# 3. Create box plots showing descriptor values grouped by `Best_Formulation` for:
#    - `MolLogP`
#    - `MolWt`
#    - `TPSA`
#
# 4. Create a correlation heatmap for the numeric descriptor columns.
#
# ## Questions
# **Q5 (10%)** Do any descriptors appear to differ systematically between formulation classes? Support your answer using your plots.
#
# **Q6 (10%)** Which descriptors appear most likely to help distinguish between `IR_tablet`, `ASD`, and `Lipid_system`? Briefly explain why.

# %%
# Your code for Section 3 goes here

# %% [markdown]
# # Section 4 — Unsupervised learning (15%)
#
# In this section, you will examine whether formulation classes occupy different regions of molecular descriptor space.
#
# ## Tasks
# 1. Build a feature matrix `X_desc` using the descriptor columns from Section 2.
# 2. Standardise the descriptor columns.
# 3. Perform **PCA** and plot **PC1 vs PC2**, colouring points by `Best_Formulation`.
# 4. Perform **KMeans clustering** (choose a reasonable value of `k`) on the standardised descriptor matrix.
# 5. Plot cluster assignments on the PCA scatter plot.
#
# ## Questions
# **Q7 (10%)** What does the PCA plot show? What do PC1 and PC2 appear to represent in terms of molecular properties?
#
# **Q8 (5%)** Do the clusters align with the known formulation classes? What might this suggest about whether formulation strategies occupy distinct regions of descriptor space?

# %%
# Your code for Section 4 goes here

# %% [markdown]
# # Section 5 — Supervised learning (20%)
#
# You will now build simple machine learning models to predict the **best formulation strategy** from molecular descriptors.
#
# ## Tasks
# 1. Define:
#    - `X` = descriptor columns from Section 2
#    - `y` = `Best_Formulation`
#
# 2. Split the data into training and test sets (e.g. 80/20).
#
# 3. Train **three** classifiers:
#    - logistic regression
#    - Random forest classifier (or another model of your choice)
#
# 4. Evaluate performance on the **test set** using:
#    - accuracy
#    - confusion matrix
#    - classification report
#
# ## Questions
# **Q9 (10%)** Do the trained models predict accurately? Which model performs best, how do you know this, and what does this suggest?
#
# **Q10 (10%)** Which descriptor features seem most important for prediction (if your model provides feature importance or coefficients)? Do these results make chemical and formulation sense?

# %%
# Your code for Section 5 goes here

# %% [markdown]
# # Section 6 — Prediction of a new molecule (10%)
#
# You are given a new molecule that the team is going to try and formulate - its SMILES is:
#
# CCCCCCCCOC(=O)NC1=CC=CC=C1
#
# Q11 (10%) Which formulation process would you recommend and why?

# %%
# Your code for Section 6 goes here

# %% [markdown]
# # Section 7 — Summary and formulation interpretation (10%)
#
# ## Q11 (10%)
# Write approximately **5 sentences** summarising:
# - key findings from exploratory analysis
# - the most important descriptor differences between formulation classes
# - what PCA/clustering suggested about molecular space
# - how well the classification model performed
# - what kinds of molecules appear most likely to require each formulation strategy

# %% [markdown]
# ---
#
# ## Academic integrity reminder
#
# Use of AI tools is recommended for debugging/syntax, but make sure you check you understand code you are running before submitting. Your analysis and interpretations should be (at least mostly!) your own.
